# %%
# importing required libraries
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# reading the drug dataset
final_df = pd.read_csv(r"C:\Users\patel\OneDrive\Desktop\AI\Project\DataSet\DiseaseDrug_dataset.csv")
final_df.head()
# Out:
#                               Drug                  Disease  \
# 0  Sulfamethoxazole / trimethoprim  urinary tract infection
# 1                     Levofloxacin  urinary tract infection
# 2  Sulfamethoxazole / trimethoprim  urinary tract infection
# 3                   Nitrofurantoin  urinary tract infection
# 4                         Macrobid  urinary tract infection
#
#                                               Review  Rating  UsefulCount  \
# 0  "I have bad side effects from all antibiotics,...       1           17
# 1  "This last Monday I was detected by my doctor ...       3           24
# 2  "I am currently suffering from recurring cysti...       1            7
# 3  "I have been taking 4 a day for last 6 days, 2...       5           10
# 4  "I wish I would have read these reviews before...       1           28
#
#                                             Symptoms
# 0  [' burning_micturition', ' bladder_discomfort'...
# 1  [' burning_micturition', ' bladder_discomfort'...
# 2  [' burning_micturition', ' bladder_discomfort'...
# 3  [' burning_micturition', ' bladder_discomfort'...
# 4  [' burning_micturition', ' bladder_discomfort'...

# %%
# initializing the instance of the sentiment analyzer
sentiment_analyser = SentimentIntensityAnalyzer()

# %%
# creating a list of reviews which can be an input for vader analysis.
list_of_reviews = list(final_df.Review)
sentiments = []
positive = []
negative = []
neutral = []
compound = []

# %%
# getting the polarity score of sentiment for the rewiews 
for rew in list_of_reviews:
  compoundS = sentiment_analyser.polarity_scores(rew)["compound"]
  positiveS = sentiment_analyser.polarity_scores(rew)["pos"]
  neutralS = sentiment_analyser.polarity_scores(rew)["neu"]
  negativeS = sentiment_analyser.polarity_scores(rew)["neg"]

  positive.append(positiveS)
  negative.append(negativeS)
  neutral.append(neutralS)
  compound.append(compoundS)
  sentiments.append({"Review":rew,
                     "Positive": positiveS,
                     "Negative": neutralS,
                     "Neutral": negativeS,
                     "Compound": compoundS})

nlp_df = pd.DataFrame.from_dict(sentiments)

# %%
nlp_df.head()
# Out:
#                                               Review  Positive  Negative  \
# 0  "I have bad side effects from all antibiotics,...     0.044     0.850
# 1  "This last Monday I was detected by my doctor ...     0.054     0.854
# 2  "I am currently suffering from recurring cysti...     0.075     0.694
# 3  "I have been taking 4 a day for last 6 days, 2...     0.070     0.642
# 4  "I wish I would have read these reviews before...     0.059     0.747
#
#    Neutral  Compound
# 0    0.106   -0.8384
# 1    0.092   -0.7825
# 2    0.231   -0.9471
# 3    0.288   -0.9669
# 4    0.195   -0.9593

# %%
# adding the sentiment analysis columns to the final dataset
final_df["Positive"] = positive
final_df["Negative"] = negative
final_df["Neutral"] = neutral
final_df["Compound"] = compound
final_df["Sentiment"] = ''

# %%
final_df.head()
# Out:
#                               Drug                  Disease  \
# 0  Sulfamethoxazole / trimethoprim  urinary tract infection
# 1                     Levofloxacin  urinary tract infection
# 2  Sulfamethoxazole / trimethoprim  urinary tract infection
# 3                   Nitrofurantoin  urinary tract infection
# 4                         Macrobid  urinary tract infection
#
#                                               Review  Rating  UsefulCount  \
# 0  "I have bad side effects from all antibiotics,...       1           17
# 1  "This last Monday I was detected by my doctor ...       3           24
# 2  "I am currently suffering from recurring cysti...       1            7
# 3  "I have been taking 4 a day for last 6 days, 2...       5           10
# 4  "I wish I would have read these reviews before...       1           28
#
#                                             Symptoms  Positive  Negative  \
# 0  [' burning_micturition', ' bladder_discomfort'...     0.044     0.106
# 1  [' burning_micturition', ' bladder_discomfort'...     0.054     0.092
# 2  [' burning_micturition', ' bladder_discomfort'...     0.075     0.231
# 3  [' burning_micturition', ' bladder_discomfort'...     0.070     0.288
# 4  [' burning_micturition', ' bladder_discomfort'...     0.059     0.195
#
#    Neutral  Compound Sentiment
# 0    0.850   -0.8384
# 1    0.854   -0.7825
# 2    0.694   -0.9471
# 3    0.642   -0.9669
# 4    0.747   -0.9593

# %%
final_df.loc[final_df['Compound'] >= 0.05, 'Sentiment'] = 'Positive'
final_df.loc[final_df['Compound'] <= -0.05, 'Sentiment'] = 'Negative'
final_df["Sentiment"].replace('', 'Neutral', inplace = True)

# %%
# deleting the positive, negative, neutral and compound columns.
final_df = final_df.drop(columns = ["Positive", "Negative", "Neutral", "Compound"])

# %%
final_df = final_df[["Disease", "Drug", "Symptoms", "Review", "Sentiment", "Rating", "UsefulCount"]]
final_df.head()
# Out:
#                    Disease                             Drug  \
# 0  urinary tract infection  Sulfamethoxazole / trimethoprim
# 1  urinary tract infection                     Levofloxacin
# 2  urinary tract infection  Sulfamethoxazole / trimethoprim
# 3  urinary tract infection                   Nitrofurantoin
# 4  urinary tract infection                         Macrobid
#
#                                             Symptoms  \
# 0  [' burning_micturition', ' bladder_discomfort'...
# 1  [' burning_micturition', ' bladder_discomfort'...
# 2  [' burning_micturition', ' bladder_discomfort'...
# 3  [' burning_micturition', ' bladder_discomfort'...
# 4  [' burning_micturition', ' bladder_discomfort'...
#
#                                               Review Sentiment  Rating  \
# 0  "I have bad side effects from all antibiotics,...  Negative       1
# 1  "This last Monday I was detected by my doctor ...  Negative       3
# 2  "I am currently suffering from recurring cysti...  Negative       1
# 3  "I have been taking 4 a day for last 6 days, 2...  Negative       5
# 4  "I wish I would have read these reviews before...  Negative       1
#
#    UsefulCount
# 0           17
# 1           24
# 2            7
# 3           10
# 4           28

# %%
# storing the final dataset into a csv file.
final_df.to_csv('C:/Users/patel/OneDrive/Desktop/AI/Project/DataSet/Sentiment_Analysis.csv',index=False)

# %%
# reading the dataset with sentiment analysis of reviews
df = pd.read_csv(r"C:\Users\patel\OneDrive\Desktop\AI\Project\DataSet\Sentiment_Analysis.csv")
df.head()
# Out:
#                    Disease                             Drug  \
# 0  urinary tract infection  Sulfamethoxazole / trimethoprim
# 1  urinary tract infection                     Levofloxacin
# 2  urinary tract infection  Sulfamethoxazole / trimethoprim
# 3  urinary tract infection                   Nitrofurantoin
# 4  urinary tract infection                         Macrobid
#
#                                             Symptoms  \
# 0  [' burning_micturition', ' bladder_discomfort'...
# 1  [' burning_micturition', ' bladder_discomfort'...
# 2  [' burning_micturition', ' bladder_discomfort'...
# 3  [' burning_micturition', ' bladder_discomfort'...
# 4  [' burning_micturition', ' bladder_discomfort'...
#
#                                               Review Sentiment  Rating  \
# 0  "I have bad side effects from all antibiotics,...  Negative       1
# 1  "This last Monday I was detected by my doctor ...  Negative       3
# 2  "I am currently suffering from recurring cysti...  Negative       1
# 3  "I have been taking 4 a day for last 6 days, 2...  Negative       5
# 4  "I wish I would have read these reviews before...  Negative       1
#
#    UsefulCount
# 0           17
# 1           24
# 2            7
# 3           10
# 4           28

# %%
#Sorting the data based on drug name
df = df.sort_values(['Drug'])

# %%
# function to calculate the weighted average
def calc_weighted_avg(group, avg_name, weight_name):
    a = group[avg_name]
    b = group[weight_name]
    try:
        return (a * b).sum() / b.sum()
    except ZeroDivisionError:
        return a.mean()

# %%
# creating a groups for diseases and their drugs based on the ratings and thier count 
df.groupby(["Disease", "Drug"]).apply(calc_weighted_avg, "Rating", "UsefulCount")
# Out:
# Disease                  Drug
# acne                     Absorica                            6.692308
#                          Acanya                              7.000000
#                          Accutane                            8.798081
#                          Acnex                              10.000000
#                          Aczone                              8.584971
#                                                               ...
# urinary tract infection  Sulfamethoxazole / trimethoprim     5.780838
#                          Trimethoprim                        3.029851
#                          Unasyn                              7.000000
#                          Uribel                              8.967213
#                          Vibramycin                         10.000000
# Length: 305, dtype: float64

# %%
df1 = pd.DataFrame(df.groupby(["Drug"]).apply(calc_weighted_avg, "Rating", "UsefulCount").reset_index())

# %%
df1 = df1.rename(columns={0: "Rating_Weighted_Avg"})

# %%
df1.head()
# Out:
#                                                 Drug  Rating_Weighted_Avg
# 0                                           Absorica             6.692308
# 1                                             Acanya             7.000000
# 2                                           Accutane             8.798081
# 3                 Acetaminophen / aspirin / caffeine             7.995652
# 4  Acetaminophen / aspirin / caffeine / salicylamide            10.000000

# %%
# combining the drug dataset with the weighted drug dataset based on similar drug
new_df = pd.merge(df1, df, on='Drug')
new_df.head()
# Out:
#        Drug  Rating_Weighted_Avg Disease  \
# 0  Absorica             6.692308    acne
# 1  Absorica             6.692308    acne
# 2    Acanya             7.000000    acne
# 3    Acanya             7.000000    acne
# 4    Acanya             7.000000    acne
#
#                                             Symptoms  \
# 0  [' skin_rash', ' pus_filled_pimples', ' blackh...
# 1  [' skin_rash', ' pus_filled_pimples', ' blackh...
# 2  [' skin_rash', ' pus_filled_pimples', ' blackh...
# 3  [' skin_rash', ' pus_filled_pimples', ' blackh...
# 4  [' skin_rash', ' pus_filled_pimples', ' blackh...
#
#                                               Review Sentiment  Rating  \
# 0  "Absorica worked right away. After the second ...  Positive       4
# 1  "My son who has tried almost every available e...  Negative       9
# 2  "I&#039;ve always been hesitant to use acne me...  Positive       9
# 3  "My dermatologist gave me Acanya to use in the...  Negative       4
# 4  "I was breaking out badly on the sides of my c...  Negative      10
#
#    UsefulCount
# 0            6
# 1            7
# 2            9
# 3           15
# 4            5

# %%
print("No. of unique drugs: ", new_df['Drug'].nunique())
new_df['Drug'].unique()
# Out:
# No. of unique drugs:  286
# array(['Absorica', 'Acanya', 'Accutane',
#        'Acetaminophen / aspirin / caffeine',
#        'Acetaminophen / aspirin / caffeine / salicylamide', 'Aciphex',
#        'Acitretin', 'Acnex', 'Aczone', 'Adalimumab', 'Adapalene',
#        'Adapalene / benzoyl peroxide', 'Adoxa', 'Aldactone',
#        'Almotriptan', 'Altabax', 'Altace',
#        'Aluminum hydroxide / magnesium hydroxide / simethicone', 'Amerge',
#        'Ammonium lactate / halobetasol', 'Amnesteem', 'Amoxicillin',
#        'Amoxicillin / clavulanate', 'Amoxil', 'Amrix', 'Aspirin',
#        'Aspirin / butalbital / caffeine', 'Atovaquone',
#        'Atovaquone / proguanil', 'Atralin', 'Augmentin', 'Avelox',
#        'Axert', 'Axid', 'Axid AR', 'Azelaic acid', 'Azelex',
#        'Azithromycin', 'Bactrim', 'Bactrim DS', 'Bayer Aspirin',
#        'BenzEFoam', 'BenzEFoam Ultra', 'Benzaclin', 'Benzoyl peroxide',
#        'Benzoyl peroxide / clindamycin',
#        'Benzoyl peroxide / erythromycin', 'Benzoyl peroxide / sulfur',
#        'Betamethasone / calcipotriene', 'Beyaz', 'Biaxin', 'Biaxin XL',
#        'Botox', 'Cafergot', 'Caffeine / ergotamine', 'Calcipotriene',
#        'Calcitriol', 'Calcium carbonate', 'Cambia', 'Carafate',
#        'Cefixime', 'Cefprozil', 'Ceftin', 'Ceftriaxone', 'Cefuroxime',
#        'Cephalexin', 'Cipro', 'Ciprofloxacin', 'Cisapride', 'Claravis',
#        'Clarifoam EF', 'Clarithromycin', 'Clindamycin',
#        'Clindamycin / tretinoin', 'Clobetasol', 'Clobex', 'Clopidogrel',
#        'Coal tar', 'Coartem', 'Cyclobenzaprine', 'Cyclosporine',
#        'Cyproheptadine', 'D.H.E. 45', 'Daclatasvir', 'Daklinza',
#        'Dapsone', 'Dasabuvir / ombitasvir / paritaprevir / ritonavir',
#        'Desonide', 'Desquam-X Wash', 'Dexilant', 'Dexlansoprazole',
#        'Diclofenac', 'Differin', 'Dihydroergotamine', 'Doribax',
#        'Doripenem', 'Doryx', 'Dovonex', 'Doxycycline',
#        'Drospirenone / ethinyl estradiol',
#        'Drospirenone / ethinyl estradiol / levomefolate calcium', 'Duac',
#        'Elbasvir / grazoprevir', 'Eletriptan', 'Elocon', 'Enbrel',
#        'Epclusa', 'Epiduo', 'Epiduo Forte', 'Esomeprazole', 'Etanercept',
#        'Ethinyl estradiol / norethindrone',
#        'Ethinyl estradiol / norgestimate', 'Excedrin', 'Famotidine',
#        'Finacea', 'Fiorinal', 'Flagyl', 'Flexeril', 'Fluocinonide',
#        'Flurandrenolide', 'Frova', 'Frovatriptan', 'Gabapentin', 'Gianvi',
#        'Gildess Fe 1 / 20', 'Gildess Fe 1.5 / 30',
#        "Goody's Extra-Strength Headache Powders", 'Halfan', 'Halobetasol',
#        'Halofantrine', 'Harvoni', 'Hexachlorophene', 'Hiprex', 'Humira',
#        'Hydrocortisone', 'Hydrocortisone / pramoxine',
#        'Hyoscyamine / methenamine / methylene blue / phenyl salicylate',
#        'Hyoscyamine / methenamine / methylene blue / phenyl salicylate / sodium biphosphate',
#        'Imitrex', 'Imitrex Nasal', 'Imitrex Statdose', 'Incivek',
#        'Inova 4 / 1', 'Interferon alfa-2b', 'Intron A', 'Isotretinoin',
#        'Junel Fe 1 / 20', 'Junel Fe 1.5 / 30', 'Kapidex', 'Kenalog',
#        'Lactobacillus acidophilus', 'Lansoprazole',
#        'Ledipasvir / sofosbuvir', 'Levaquin', 'Levofloxacin', 'Lidex',
#        'Lisinopril', 'Loestrin 24 Fe', 'Loestrin Fe 1 / 20', 'Loryna',
#        'MG217 Medicated Tar', 'Macrobid', 'Macrodantin', 'Maxalt',
#        'Maxalt-MLT', 'Mefloquine', 'Methenamine', 'Methergine',
#        'Methimazole', 'Methotrexate', 'Methylergonovine',
#        'Metoclopramide', 'Metoprolol', 'Metoprolol Tartrate',
#        'Metronidazole', 'Microgestin Fe 1 / 20', 'Migergot', 'Migranal',
#        'Minocin', 'Minocycline', 'Moderiba', 'Mometasone', 'Monodox',
#        'Moxifloxacin', 'Naproxen / sumatriptan', 'Naratriptan',
#        'Necon 1 / 35', 'Necon 7 / 7 / 7', 'Neurontin', 'Nexium',
#        'Nitrofurantoin', 'Nitroglycerin', 'Nizatidine', 'Nortrel 1 / 35',
#        'NuOx', 'Ocella', 'Olux', 'Olysio', 'Omeprazole',
#        'Omeprazole / sodium bicarbonate', 'OnabotulinumtoxinA',
#        'Ondansetron', 'Onexton', 'Orphenadrine', 'Ortho Tri-Cyclen',
#        'Pantoprazole', 'Pegasys', 'Peginterferon alfa-2a',
#        "Phillips' Milk of Magnesia", 'Piperacillin / tazobactam',
#        'Plavix', 'Pramosone', 'Prevacid', 'Prilosec', 'Prilosec OTC',
#        'Propulsid', 'Protonix', 'Psoriasin', 'Rabeprazole', 'Ranitidine',
#        'Reglan', 'Relpax', 'Retapamulin', 'Retin-A', 'Ribasphere',
#        'Ribavirin', 'Rizatriptan', 'Rocephin', 'SMZ-TMP DS',
#        'Salicylic acid', 'Salicylic acid / sulfur', 'Septra',
#        'Sofosbuvir', 'Sofosbuvir / velpatasvir', 'Solodyn', 'Sotret',
#        'Sovaldi', 'Spironolactone', 'Stelara', 'Sucralfate',
#        'Sulfacetamide sodium / sulfur', 'Sulfamethoxazole / trimethoprim',
#        'Sumatriptan', 'Sumavel DosePro', 'Taclonex', 'Taclonex Scalp',
#        'Tazarotene', 'Tazorac', 'Telaprevir', 'Temovate', 'Tenofovir',
#        'Tetracycline', 'Topicort', 'Tretin-X', 'Tretinoin', 'Treximet',
#        'Tri-Previfem', 'Tri-Sprintec', 'TriNessa', 'Triamcinolone',
#        'Trimethoprim', 'Unasyn', 'Uribel', 'Ustekinumab', 'Vanoxide-HC',
#        'Vantin', 'Vectical', 'Veltin', 'Vibramycin', 'Viread', 'Yasmin',
#        'Yaz', 'Zantac', 'Zantac 150', 'Zecuity', 'Zegerid', 'Zegerid OTC',
#        'Zenatane', 'Zepatier', 'Ziana', 'Zofran', 'Zolmitriptan', 'Zomig',
#        'Zomig-ZMT', 'femhrt'], dtype=object)

# %%
print("No. of unique diseases: ", new_df['Disease'].nunique())
new_df['Disease'].unique()
# Out:
# No. of unique diseases:  12
# array(['acne', 'migraine', 'gerd', 'psoriasis', 'heart attack',
#        'urinary tract infection', 'pneumonia', 'malaria', 'hepatitis c',
#        'hyperthyroidism', 'gastroenteritis', 'hepatitis b'], dtype=object)

# %%
#Sorting dataset and grouping by disease
new_df = new_df.sort_values(['Disease','Rating_Weighted_Avg'],ascending=False, ignore_index=True).groupby('Disease').head()
new_df.head()
# Out:
#                         Drug  Rating_Weighted_Avg                  Disease  \
# 0                   Cefixime                 10.0  urinary tract infection
# 1                    Doribax                 10.0  urinary tract infection
# 2                  Doripenem                 10.0  urinary tract infection
# 3  Lactobacillus acidophilus                 10.0  urinary tract infection
# 4                Macrodantin                 10.0  urinary tract infection
#
#                                             Symptoms  \
# 0  [' burning_micturition', ' bladder_discomfort'...
# 1  [' burning_micturition', ' bladder_discomfort'...
# 2  [' burning_micturition', ' bladder_discomfort'...
# 3  [' burning_micturition', ' bladder_discomfort'...
# 4  [' burning_micturition', ' bladder_discomfort'...
#
#                                               Review Sentiment  Rating  \
# 0  "My daughter was born with urinary reflux, the...  Negative      10
# 1  "It is proved itself it is an excellent drug o...  Positive      10
# 2  "It is proved itself it is an excellent drug o...  Positive      10
# 3  "This has been a miracle for me, and it was by...  Negative      10
# 4  "Started experiecing pain peeing and went for ...  Positive      10
#
#    UsefulCount
# 0            7
# 1            1
# 2            1
# 3          189
# 4           28

# %%
# storing the dataset contaning the calculated weighted average into a csv file
new_df.to_csv('C:/Users/patel/OneDrive/Desktop/AI/Project/DataSet/Drug_Recommendation_data.csv',index=False)
