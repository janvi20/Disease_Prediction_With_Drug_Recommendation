# %% [markdown]
# #### Disease Symptom Data Preprocessing

# %% [markdown]
# ###### Importing required libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data Preprocessing

# %%
# reading the dataset
disease_df = pd.read_csv(r"C:\Users\patel\OneDrive\Desktop\AI\Project\DataSet\dataset.csv")
disease_df.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
disease_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     4920 non-null   object
#  1   Symptom_1   4920 non-null   object
#  2   Symptom_2   4920 non-null   object
#  3   Symptom_3   4920 non-null   object
#  4   Symptom_4   4572 non-null   object
#  5   Symptom_5   3714 non-null   object
#  6   Symptom_6   2934 non-null   object
#  7   Symptom_7   2268 non-null   object
#  8   Symptom_8   1944 non-null   object
#  9   Symptom_9   1692 non-null   object
#  10  Symptom_10  1512 non-null   object
#  11  Symptom_11  1194 non-null   object
#  12  Symptom_12  744 non-null    object
#  13  Symptom_13  504 non-null    object
#  14  Symptom_14  306 non-null    object
#  15  Symptom_15  240 non-null    object
#  16  Symptom_16  192 non-null    object
#  17  Symptom_17  72 non-null     object
# dtypes: object(18)
# memory usage: 692.0+ KB

# %%
# getting the statistical information of the datset
disease_df.describe()
# Out:
#                  Disease  Symptom_1  Symptom_2 Symptom_3    Symptom_4  \
# count               4920       4920       4920      4920         4572
# unique                41         34         48        54           50
# top     Fungal infection   vomiting   vomiting   fatigue   high_fever
# freq                 120        822        870       726          378
#
#         Symptom_5 Symptom_6        Symptom_7        Symptom_8  \
# count        3714      2934             2268             1944
# unique         38        32               26               21
# top      headache    nausea   abdominal_pain   abdominal_pain
# freq          348       390              264              276
#
#                  Symptom_9          Symptom_10     Symptom_11 Symptom_12  \
# count                 1692                1512           1194        744
# unique                  22                  21             18         11
# top      yellowing_of_eyes   yellowing_of_eyes   irritability    malaise
# ...

# %%
# finding null values
disease_df.isnull().sum()
# Out:
# Disease          0
# Symptom_1        0
# Symptom_2        0
# Symptom_3        0
# Symptom_4      348
# Symptom_5     1206
# Symptom_6     1986
# Symptom_7     2652
# Symptom_8     2976
# Symptom_9     3228
# Symptom_10    3408
# Symptom_11    3726
# Symptom_12    4176
# Symptom_13    4416
# Symptom_14    4614
# Symptom_15    4680
# Symptom_16    4728
# Symptom_17    4848
# dtype: int64

# %%
cols = disease_df.columns
data = disease_df[cols].values.flatten()

s = pd.Series(data)
s = s.str.strip()
s = s.values.reshape(disease_df.shape)

disease_df = pd.DataFrame(s, columns=disease_df.columns)
disease_df.head()
# Out:
#             Disease  Symptom_1             Symptom_2             Symptom_3  \
# 0  Fungal infection    itching             skin_rash  nodal_skin_eruptions
# 1  Fungal infection  skin_rash  nodal_skin_eruptions   dischromic _patches
# 2  Fungal infection    itching  nodal_skin_eruptions   dischromic _patches
# 3  Fungal infection    itching             skin_rash   dischromic _patches
# 4  Fungal infection    itching             skin_rash  nodal_skin_eruptions
#
#              Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0  dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                  NaN       NaN       NaN       NaN       NaN       NaN
# 2                  NaN       NaN       NaN       NaN       NaN       NaN
# 3                  NaN       NaN       NaN       NaN       NaN       NaN
# 4                  NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_10 Symptom_11 Symptom_12
# 0        NaN        NaN        NaN
# ...

# %%
# creating a dictionary to store list of symptoms related to that particular disease 
diseaseDict = disease_df.set_index('Disease').T.to_dict('list')
print(diseaseDict)
# Out:
# {'Fungal infection': ['itching', 'skin_rash', 'nodal_skin_eruptions', 'dischromic _patches', nan, nan, nan, nan, nan, nan, nan, nan], 'Allergy': ['continuous_sneezing', 'shivering', 'chills', 'watering_from_eyes', nan, nan, nan, nan, nan, nan, nan, nan], 'GERD': ['stomach_pain', 'acidity', 'ulcers_on_tongue', 'vomiting', 'cough', 'chest_pain', nan, nan, nan, nan, nan, nan], 'Chronic cholestasis': ['itching', 'vomiting', 'yellowish_skin', 'nausea', 'loss_of_appetite', 'abdominal_pain', 'yellowing_of_eyes', nan, nan, nan, nan, nan], 'Drug Reaction': ['itching', 'skin_rash', 'stomach_pain', 'burning_micturition', 'spotting_ urination', nan, nan, nan, nan, nan, nan, nan], 'Peptic ulcer diseae': ['vomiting', 'indigestion', 'loss_of_appetite', 'abdominal_pain', 'passage_of_gases', 'internal_itching', nan, nan, nan, nan, nan, nan], 'AIDS': ['muscle_wasting', 'patches_in_throat', 'high_fever', 'extra_marital_contacts', nan, nan, nan, nan, nan, nan, nan, nan], 'Diabetes': ['fatigue', 'weight_
# ...

# %%
#Combine symptoms for a particluar disease
final_disease_df = pd.DataFrame(list(diseaseDict.items()), columns=['Disease','Symptom'])
final_disease_df.head()
# Out:
#                Disease                                            Symptom
# 0     Fungal infection  [itching, skin_rash, nodal_skin_eruptions, dis...
# 1              Allergy  [continuous_sneezing, shivering, chills, water...
# 2                 GERD  [stomach_pain, acidity, ulcers_on_tongue, vomi...
# 3  Chronic cholestasis  [itching, vomiting, yellowish_skin, nausea, lo...
# 4        Drug Reaction  [itching, skin_rash, stomach_pain, burning_mic...

# %%
# filling null values with 0
disease_df = disease_df.fillna(0)
disease_df.isnull().sum()

# %% [markdown]
# ### Disease Prediction

# %% [markdown]
# ##### Getting the top 10 disease

# %% [markdown]
# ##### Finding the coorelation between the symptoms and the disease

# %% [markdown]
# #### Training the data

# %% [markdown]
# ##### Finding the best value of K for training the K-Means Model

# %%
classifier = KNeighborsClassifier(n_neighbors=1)
classifier.fit(trainX, trainY)
y_pred = classifier.predict(testX)

# %%
#print(classification_report(testY, y_pred))

# %% [markdown]
# ##### Manual Disease Prediction

# %%
def predictions(S1,S2,S3,S4,S5,S6,S7,S8,S9,S10,S11,S12,x):
    symptomsList = [S1,S2,S3,S4,S5,S6,S7,S8,S9,S10,S11,S12]
    print(symptomsList)
    sympts = np.array(disease_severity_df["Symptom"])
    weights = np.array(disease_severity_df["weight"])
    for j in range(len(symptomsList)):
        for k in range(len(sympts)):
            if symptomsList[j]==sympts[k]:
                symptomsList[j]=weights[k]

    psy = [symptomsList]

    yPredictions = x.predict(psy)
    print("The predicted disease is",yPredictions[0])

# %%
sympList = disease_severity_df["Symptom"].to_list()
predictions(sympList[7],sympList[5],sympList[2],sympList[80],0,0,0,0,0,0,0,0,classifier)
